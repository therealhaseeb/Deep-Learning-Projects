# %%
import pandas as pd
import numpy as np

# %%
# from google.colab import files
# up = files.upload()

# %%
data = pd.read_csv('winequality-white.csv', delimiter=';')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# Separating Data
x = data.values[:,0:11]
print(len(x))

from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
x = min_max_scaler.fit_transform(x)
print(x)

# Total Of 4898 Rows
# --------------------
# Train Data
train_data = x[0:3000]
print(len(train_data))

# Test Data
test_data = x[3000:]
print(len(test_data))
# Out:
# 4898
# [[0.30769231 0.18627451 0.21686747 ... 0.25454545 0.26744186 0.12903226]
#  [0.24038462 0.21568627 0.20481928 ... 0.52727273 0.31395349 0.24193548]
#  [0.41346154 0.19607843 0.24096386 ... 0.49090909 0.25581395 0.33870968]
#  ...
#  [0.25961538 0.15686275 0.11445783 ... 0.24545455 0.27906977 0.22580645]
#  [0.16346154 0.20588235 0.18072289 ... 0.56363636 0.18604651 0.77419355]
#  [0.21153846 0.12745098 0.22891566 ... 0.49090909 0.11627907 0.61290323]]
# 3000
# 1898

# %%
# Separating Labels
y = data.values[:,11]
print(y.shape)

# Total Of 4898 Rows
# --------------------
# Train Data
# print(train_label.shape)
# Test Data
# print(test_label.shape)
# Out:
# (4898,)

# %%
from keras.utils import to_categorical

y = to_categorical(y)
print(y.shape)

print(train_label.shape)
print(test_label.shape)

train_label = y[0:3000]

test_label = y[3000:]
# Out:
# (4898, 10)
# (3000, 10)
# (1898, 10)

# %%
from keras import models
from keras import layers

# %%
def baseline_model():
  network = models.Sequential()
  network.add(layers.Dense(11, activation='relu', input_dim=11))
  network.add(layers.Dense(15, activation='relu'))
  # network.add(layers.Dense(8, activation='relu'))
  # network.add(layers.Dense(4, activation='relu'))
  network.add(layers.Dense(10, activation='softmax'))
  network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
  return network

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFoldhttps://lh3.googleusercontent.com/a/default-user=s128
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

estimator = KerasClassifier(build_fn=baseline_model, epochs=100, batch_size=10, verbose=2)

kfold = KFold(n_splits=5, shuffle=True)

results = cross_val_score(estimator, test_data, test_label, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
#  - 2s - loss: 1.7929 - acc: 0.3775
# Epoch 2/100
#  - 1s - loss: 1.2545 - acc: 0.5040
# Epoch 3/100
#  - 1s - loss: 1.1960 - acc: 0.5040
# Epoch 4/100
#  - 1s - loss: 1.1682 - acc: 0.5046
# Epoch 5/100
#  - 1s - loss: 1.1476 - acc: 0.5079
# Epoch 6/100
#  - 1s - loss: 1.1320 - acc: 0.5257
# Epoch 7/100
#  - 1s - loss: 1.1208 - acc: 0.5343
# Epoch 8/100
#  - 1s - loss: 1.1096 - acc: 0.5428
# Epoch 9/100
#  - 1s - loss: 1.1062 - acc: 0.5520
# Epoch 10/100
#  - 1s - loss: 1.0997 - acc: 0.5567
# Epoch 11/100
#  - 1s - loss: 1.0924 - acc: 0.5580
# Epoch 12/100
#  - 1s - loss: 1.0893 - acc: 0.5619
# Epoch 13/100
#  - 1s - loss: 1.0862 - acc: 0.5632
# Epoch 14/100
#  - 1s - loss: 1.0788 - acc: 0.5580
# Epoch 15/100
#  - 1s - loss: 1.0774 - acc: 0.5619
# Epoch 16/100
#  - 1s - loss: 1.0753 - acc: 0.5632
# Epoch 17/100
#  - 1s - loss: 1.0690 - acc: 0.5777
# Epoch 18/100
#  - 1s - loss: 1.0670 - acc: 0.5685
# Epoch 19/100
#  - 1s - loss: 1.0658 - acc: 0.5692
# Epoch 20/100
# ...

# %%
network.evaluate(test_data, test_label)
# Out:
# 1898/1898 [==============================] - 1s 353us/step
# [1.1199205296685246, 0.5021074815595363]
